# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
family = pd.read_csv('Data/familyxx.csv')
family["family_id"] = family["HHX"] + family["SRVY_YR"] + family["FMX"]
family.head()

person = pd.read_csv('Data/personsx.csv')
person["family_id"] = person["HHX"] + person["SRVY_YR"] + person["FMX"]
person.head()

merged = person.merge(family, on = 'family_id', how='inner')
merged
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73728    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73729    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73730    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 73731    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73732    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0           1.0  ...      NaN        1         2         2       NaN     2
# 1           2.0  ...      4.0        2         1         1       1.0     2
# 2           0.0  ...      4.0        2         1         1       1.0     2
# 3           NaN  ...      4.0        2         1         1       1.0     2
# 4           1.0  ...      1.0        2         2         2       NaN     1
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73728       1.0  ...      1.0        1         2         2       NaN     2
# 73729       1.0  ...      4.0        5         1         1       2.0     2
# 73730       1.0  ...      2.0        2         2         2       NaN     2
# 73731       2.0  ...      2.0        2         2         2       NaN     2
# 73732       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0             1         1      NaN       NaN
# 1             3         1      2.0       3.0
# 2             3         1      2.0       3.0
# 3             3         1      2.0       3.0
# 4             4         1      2.0       4.0
# ...         ...       ...      ...       ...
# 73728         1         1      NaN       1.0
# 73729         1         1      2.0       1.0
# 73730         2         1      2.0       2.0
# 73731         2         1      2.0       2.0
# 73732         1         1      2.0       0.0
#
# [73733 rows x 730 columns]

# %%
merged = merged[merged["FDMEDYN"] < 7]
merged
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73728    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73729    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73730    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 73731    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73732    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0           1.0  ...      NaN        1         2         2       NaN     2
# 1           2.0  ...      4.0        2         1         1       1.0     2
# 2           0.0  ...      4.0        2         1         1       1.0     2
# 3           NaN  ...      4.0        2         1         1       1.0     2
# 4           1.0  ...      1.0        2         2         2       NaN     1
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73728       1.0  ...      1.0        1         2         2       NaN     2
# 73729       1.0  ...      4.0        5         1         1       2.0     2
# 73730       1.0  ...      2.0        2         2         2       NaN     2
# 73731       2.0  ...      2.0        2         2         2       NaN     2
# 73732       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0             1         1      NaN       NaN
# 1             3         1      2.0       3.0
# 2             3         1      2.0       3.0
# 3             3         1      2.0       3.0
# 4             4         1      2.0       4.0
# ...         ...       ...      ...       ...
# 73728         1         1      NaN       1.0
# 73729         1         1      2.0       1.0
# 73730         2         1      2.0       2.0
# 73731         2         1      2.0       2.0
# 73732         1         1      2.0       0.0
#
# [73706 rows x 730 columns]

# %%
merged["LACHRC17"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 73728   NaN
# 73729   NaN
# 73730   NaN
# 73731   NaN
# 73732   NaN
# Name: LACHRC17, Length: 73706, dtype: float64

# %%
# for checking number of null values
# for i in merged.columns:
 #   if(merged[i].isnull().sum() > 0):
  #      merged = merged.drop([i], axis=1)

# %%
y_delay = merged[merged["FDMEDYN"] == 1]
y_delay
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 11       1      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 12       1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73692    3      NaN         4    1    NaN      NaN     NaN     NaN      NaN
# 73693    4      NaN         4    1    NaN      NaN     NaN     NaN      NaN
# 73725    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73727    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73729    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 1           2.0  ...      4.0        2         1         1       1.0     2
# 2           0.0  ...      4.0        2         1         1       1.0     2
# 3           NaN  ...      4.0        2         1         1       1.0     2
# 11          1.0  ...      NaN        2         1         1       1.0     2
# 12          1.0  ...      2.0        5         1         1       1.0     2
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73692       NaN  ...      4.0        4         2         2       NaN     2
# 73693       NaN  ...      4.0        4         2         2       NaN     2
# 73725       1.0  ...      NaN        2         1         2       1.0     2
# 73727       1.0  ...      NaN        2         1         2       1.0     2
# 73729       1.0  ...      4.0        5         1         1       2.0     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 1             3         1      2.0       3.0
# 2             3         1      2.0       3.0
# 3             3         1      2.0       3.0
# 11            1         1      2.0       0.0
# 12            4         1      1.0       4.0
# ...         ...       ...      ...       ...
# 73692         4         1      2.0       4.0
# 73693         4         1      2.0       4.0
# 73725         0         2      NaN       NaN
# 73727         0         2      NaN       NaN
# 73729         1         1      2.0       1.0
#
# [10305 rows x 730 columns]

# %%
n_delay = merged[merged["FDMEDYN"] == 2]
n_delay
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# 5        2      NaN         1    2    2.0      1.0     NaN     NaN      NaN
# 6        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 7        4      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73726    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73728    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73730    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 73731    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73732    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0           1.0  ...      NaN        1         2         2       NaN     2
# 4           1.0  ...      1.0        2         2         2       NaN     1
# 5           2.0  ...      1.0        2         2         2       NaN     1
# 6           NaN  ...      1.0        2         2         2       NaN     1
# 7           NaN  ...      1.0        2         2         2       NaN     1
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73726       1.0  ...      2.0        1         2         2       NaN     2
# 73728       1.0  ...      1.0        1         2         2       NaN     2
# 73730       1.0  ...      2.0        2         2         2       NaN     2
# 73731       2.0  ...      2.0        2         2         2       NaN     2
# 73732       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0             1         1      NaN       NaN
# 4             4         1      2.0       4.0
# 5             4         1      2.0       4.0
# 6             4         1      2.0       4.0
# 7             4         1      2.0       4.0
# ...         ...       ...      ...       ...
# 73726         1         1      NaN       1.0
# 73728         1         1      NaN       1.0
# 73730         2         1      2.0       2.0
# 73731         2         1      2.0       2.0
# 73732         1         1      2.0       0.0
#
# [63401 rows x 730 columns]

# %% [markdown]
# #### Family sizes for families that delayed and families that didn't are similar

# %%
y_delay["FM_SIZE"].describe()
# Out:
# count    10305.000000
# mean         3.308685
# std          1.825753
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         13.000000
# Name: FM_SIZE, dtype: float64

# %%
n_delay["FM_SIZE"].describe()
# Out:
# count    63401.000000
# mean         3.234397
# std          1.689117
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         12.000000
# Name: FM_SIZE, dtype: float64

# %% [markdown]
# #### Those who didn't delay were on the older side but still similar in age to those who delayed

# %%
y_delay["AGE_P"].describe()
# Out:
# count    10305.000000
# mean        37.236875
# std         21.189219
# min          0.000000
# 25%         19.000000
# 50%         37.000000
# 75%         55.000000
# max         85.000000
# Name: AGE_P, dtype: float64

# %%
n_delay["AGE_P"].describe()
# Out:
# count    63401.000000
# mean        40.277882
# std         23.631284
# min          0.000000
# 25%         19.000000
# 50%         40.000000
# 75%         60.000000
# max         85.000000
# Name: AGE_P, dtype: float64

# %% [markdown]
# #### Those who delayed care had a lower family income to poverty threshold

# %%
y_delay["RAT_CAT4"].describe()
# Out:
# count    10305.000000
# mean        13.866958
# std         20.567060
# min          1.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         99.000000
# Name: RAT_CAT4, dtype: float64

# %%
n_delay["RAT_CAT4"].describe()
# Out:
# count    63401.000000
# mean        16.916105
# std         22.652433
# min          1.000000
# 25%          8.000000
# 50%         13.000000
# 75%         14.000000
# max         99.000000
# Name: RAT_CAT4, dtype: float64

# %% [markdown]
# #### Similar responses when asked if anyone in the family had health insurance
# look at percent instead, not 1 or 2

# %%
n_delay["FHICOVYN"].describe()
# Out:
# count    63401.000000
# mean         1.049447
# std          0.406725
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          9.000000
# Name: FHICOVYN, dtype: float64

# %%
y_delay["FHICOVYN"].describe()
# approx 10% didn't have health insurance --> look at breakdown of 1s and 2s, calculate standard error w/ bellcurve, enough respondents so 90 v 95% still makes a differ
# Out:
# count    10305.000000
# mean         1.105774
# std          0.387938
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          9.000000
# Name: FHICOVYN, dtype: float64

# %%
merged.head()
# Out:
#     FPX  INTV_QRT  SEX  FMX_x  RRP  FRRP  ORIGIN_I  HISPAN_I  RACRECI3  \
# 1     1         1    2      1    1     1         2        12         1
# 11    1         1    1      1    1     1         2        12         3
# 12    1         1    1      1    1     1         2        12         1
# 27    2         1    2      1    2     2         2        12         1
# 33    2         1    2      1    2     2         2        12         1
#
#     R_MARITL  ...  FHIPUBCT  FHIOGVCT  FHIIHSCT  FHIEXCT  FHICOST  FMEDBILL  \
# 1          1  ...         0         0         0        0        2         1
# 11         4  ...         0         0         0        0        2         1
# 12         1  ...         0         0         0        0        5         1
# 27         1  ...         0         0         0        0        5         2
# 33         1  ...         0         0         0        0        1         2
#
#     FMEDBPAY  FSAF  FHICOVCT  FHICOVYN
# 1          1     2         3         1
# 11         1     2         1         1
# 12         1     2         4         1
# 27         2     1         2         1
# 33         2     2         2         1
#
# [5 rows x 189 columns]

# %%
merged.loc[merged["FLAADLYN"] == 1]
# Out:
#        FPX  INTV_QRT  SEX  FMX_x  RRP  FRRP  ORIGIN_I  HISPAN_I  RACRECI3  \
# 11       1         1    1      1    1     1         2        12         3
# 63       1         1    2      1    1     1         2        12         1
# 64       2         1    2      1    4     4         2        12         1
# 65       3         1    1      1    4     4         2        12         1
# 109      1         1    1      1    1     1         2        12         1
# ...    ...       ...  ...    ...  ...   ...       ...       ...       ...
# 73589    1         4    1      1    1     1         2        12         2
# 73590    2         4    2      1    2     2         2        12         2
# 73662    1         4    2      1    1     1         2        12         1
# 73663    2         4    1      1    4     4         2        12         1
# 73706    1         4    2      1    1     1         2        12         2
#
#        R_MARITL  ...  FHIPUBCT  FHIOGVCT  FHIIHSCT  FHIEXCT  FHICOST  \
# 11            4  ...         0         0         0        0        2
# 63            5  ...         0         0         0        0        1
# 64            7  ...         0         0         0        0        1
# 65            7  ...         0         0         0        0        1
# 109           1  ...         0         0         0        0        1
# ...         ...  ...       ...       ...       ...      ...      ...
# 73589         1  ...         0         0         0        0        4
# 73590         1  ...         0         0         0        0        4
# 73662         9  ...         0         0         0        0        1
# 73663         7  ...         0         0         0        0        1
# 73706         5  ...         0         0         0        0        1
#
#        FMEDBILL  FMEDBPAY  FSAF  FHICOVCT  FHICOVYN
# 11            1         1     2         1         1
# 63            2         2     2         3         1
# 64            2         2     2         3         1
# 65            2         2     2         3         1
# 109           2         2     2         2         1
# ...         ...       ...   ...       ...       ...
# 73589         2         2     2         2         1
# 73590         2         2     2         2         1
# 73662         2         2     2         2         1
# 73663         2         2     2         2         1
# 73706         1         1     2         1         1
#
# [3803 rows x 189 columns]

# %%
merged.loc[merged["FLAADLYN"] == 2]
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73728    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73729    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73730    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 73731    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73732    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0           1.0  ...      NaN        1         2         2       NaN     2
# 1           2.0  ...      4.0        2         1         1       1.0     2
# 2           0.0  ...      4.0        2         1         1       1.0     2
# 3           NaN  ...      4.0        2         1         1       1.0     2
# 4           1.0  ...      1.0        2         2         2       NaN     1
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73728       1.0  ...      1.0        1         2         2       NaN     2
# 73729       1.0  ...      4.0        5         1         1       2.0     2
# 73730       1.0  ...      2.0        2         2         2       NaN     2
# 73731       2.0  ...      2.0        2         2         2       NaN     2
# 73732       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0             1         1      NaN       NaN
# 1             3         1      2.0       3.0
# 2             3         1      2.0       3.0
# 3             3         1      2.0       3.0
# 4             4         1      2.0       4.0
# ...         ...       ...      ...       ...
# 73728         1         1      NaN       1.0
# 73729         1         1      2.0       1.0
# 73730         2         1      2.0       2.0
# 73731         2         1      2.0       2.0
# 73732         1         1      2.0       0.0
#
# [69887 rows x 730 columns]

# %%
merged = merged.drop(merged.query('FLAADLYN == 2').sample(frac=.95).index)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-55-6de6a9d614bc> in <module>
# ----> 1 merged = merged.drop(merged.query('FLAADLYN == 2').sample(frac=.95).index)
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3342
#    3343         try:
# -> 3344             result = self.loc[res]
#    3345         except ValueError:
#    3346             # when res is multi-dimensional loc raises, but this is sometimes a
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#    1092
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
# --> 898         return self.obj._take_with_is_copy(inds, axis=axis)
#     899
#     900
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
#    3365         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3348         self._consolidate_inplace()
#    3349
# -> 3350         new_data = self._mgr.take(
#    3351             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3352         )
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1445
#    1446         new_labels = self.axes[axis].take(indexer)
# -> 1447         return self.reindex_indexer(
#    1448             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1449         )
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
# -> 1284             new_blocks = [
#    1285                 blk.take_nd(
#    1286                     indexer,
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1283         else:
#    1284             new_blocks = [
# -> 1285                 blk.take_nd(
#    1286                     indexer,
#    1287                     axis=axis,
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1253             allow_fill = True
#    1254
# -> 1255         new_values = algos.take_nd(
#    1256             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1257         )
#
# D:\Anaconda\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1706             out = np.empty(out_shape, dtype=dtype, order="F")
#    1707         else:
# -> 1708             out = np.empty(out_shape, dtype=dtype)
#    1709
#    1710     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 287. MiB for an array with shape (539, 69887) and data type float64

# %%
X = merged[["FINCINT", "OTHGOV", "PHCHM2W", "FINT_Y_P", "HIKINDNC", "OTHPUB", "HIKINDNG", "PLAWALK", "PTANF", "IHS", "HIKINDNE"]]
y = merged["FDMEDYN"]

# removed cos lowest importance "FOWBENYN"

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler as ss
sc = ss()

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()

rf_model.fit(X_train, y_train)

y_pred_class = rf_model.predict(X_train)
training_accuracy = metrics.accuracy_score(y_train, y_pred_class)
training_error = 1 - training_accuracy

y_pred_class = rf_model.predict(X_test)
testing_accuracy = metrics.accuracy_score(y_test, y_pred_class)
testing_error = 1 - testing_accuracy
print("Test accuracy: {0}, Test error: {1}".format(testing_accuracy, testing_error))
# Out:
# Test accuracy: 0.7990430622009569, Test error: 0.2009569377990431

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.01      0.01       294
#            2       0.80      1.00      0.89      1169
#
#     accuracy                           0.80      1463
#    macro avg       0.65      0.50      0.45      1463
# weighted avg       0.74      0.80      0.71      1463

# %%
# sort by highest feature importance
sorted_idx = rf_model.feature_importances_.argsort()
sorted_idx
X.columns[sorted_idx]
# Out:
# Index(['FINCINT', 'IHS', 'FINT_Y_P', 'HIKINDNG', 'OTHPUB', 'HIKINDNE',
#        'OTHGOV', 'HIKINDNC', 'PTANF', 'PHCHM2W', 'PLAWALK'],
#       dtype='object')

# %%
# sort by highest feature importance
sorted_idx = rf_model.feature_importances_.argsort()
#plt.barh(X.columns[sorted_idx], rf_model.feature_importances_[sorted_idx], color='black')
plt.barh(X.columns[sorted_idx], rf_model.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
rf_model.feature_importances_[sorted_idx]
# Out:
# array([0.02418556, 0.03107928, 0.03410561, 0.03412293, 0.04660736,
#        0.04734769, 0.05175791, 0.06416933, 0.18833473, 0.19785124,
#        0.28043836])

# %%
for i in range(10):
    print("\"" + X.columns[sorted_idx][i] + "\"" + ", ", end="")
# Out:
# "OTHGOV", "IHS", "FINT_Y_P", "FINCINT", "HIKINDNG", "OTHPUB", "HIKINDNE", "HIKINDNC", "PTANF", "PHCHM2W",

# %%
y_delay["PHCHM2W"].describe()
# Out:
# count    10305.000000
# mean         1.989326
# std          0.173682
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          9.000000
# Name: PHCHM2W, dtype: float64

# %%
n_delay["PHCHM2W"].describe()
# Out:
# count    63401.000000
# mean         1.988738
# std          0.155649
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          9.000000
# Name: PHCHM2W, dtype: float64

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import tree

# %%
clf = DecisionTreeClassifier(max_depth = 2, 
                             random_state = 0)

clf.fit(X_train, y_train)

y_pred_class = clf.predict(X_test)

testing_accuracy = metrics.accuracy_score(y_test, y_pred_class)
testing_error = 1 - testing_accuracy
print("Test accuracy: {0}, Test error: {1}".format(testing_accuracy, testing_error))
# Out:
# Test accuracy: 0.8615520282186949, Test error: 0.13844797178130508

# %%
tree.plot_tree(clf);

# %%
print(X.columns[7])
print(X.columns[4])
print(X.columns[2])
# Out:
# PLAWALK
# HIKINDNC
# PHCHM2W

# %% [markdown]
# Top Features
# For RF model take into consideration that model performed best with the people who didn't delay care hence these traits may be more indicative of that group
# 1) PLAWALK
# - Does have difficulty walking without equipment?
# - Factor possibly related to accessibility
#
# 2) PHCHM2W
# - Did receive HOME care by health professional, 2 wk
# - Factor possibly related to accessibility
#
# 3) PTANF
# - Received income from a state or county welfare program (e.g., TANF)
# - Cost/affordability related factor

# %%
merged[merged['PSEINC']==1]
# Out:
#        FPX  INTV_QRT  SEX  FMX_x  RRP  FRRP  ORIGIN_I  HISPAN_I  RACRECI3  \
# 41       1         1    1      1    1     1         2        12         1
# 49       1         1    2      1    2     2         2        12         1
# 90       1         1    1      1    1     1         2        12         1
# 99       1         1    2      1    1     1         2        12         1
# 100      2         1    1      1    2     2         2        12         1
# ...    ...       ...  ...    ...  ...   ...       ...       ...       ...
# 73645    2         4    1      1    2     2         2        12         1
# 73647    2         4    1      1    2     2         2        12         1
# 73653    1         4    2      1    1     1         2        12         1
# 73660    2         4    1      1    2     2         2        12         3
# 73717    2         4    2      1    2     2         2        12         1
#
#        R_MARITL  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 41            7  ...      NaN        1         2         2       NaN     2
# 49            1  ...      3.0        1         2         1       NaN     2
# 90            7  ...      2.0        2         2         2       NaN     2
# 99            1  ...      3.0        2         2         2       NaN     2
# 100           1  ...      3.0        2         2         2       NaN     2
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73645         1  ...      NaN        4         2         2       NaN     2
# 73647         1  ...      4.0        2         2         2       NaN     2
# 73653         1  ...      NaN        3         2         2       NaN     2
# 73660         1  ...      NaN        1         2         2       NaN     2
# 73717         1  ...      2.0        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 41            1         1      2.0       0.0
# 49            2         1      2.0       2.0
# 90            1         1      2.0       1.0
# 99            2         1      2.0       1.0
# 100           2         1      2.0       1.0
# ...         ...       ...      ...       ...
# 73645         0         2      NaN       NaN
# 73647         3         1      2.0       1.0
# 73653         2         1      NaN       NaN
# 73660         3         1      NaN       NaN
# 73717         2         1      2.0       2.0
#
# [5414 rows x 414 columns]

# %%
# PDMED12M Has medical care been delayed for - - (cost), 12m 
# PSAL Received income from wages or salary (last CY)
y = merged['FDMEDYN']
y.value_counts().sort_index()
# Out:
# 1    10305
# 2    63401
# Name: FDMEDYN, dtype: int64

# %%
merged = person.merge(family, on = 'family_id', how='inner')
merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63d395fbade0> in <module>
# ----> 1 merged = person.merge(family, on = 'family_id', how='inner')
#       2 merged
#
# NameError: name 'person' is not defined

# %%
X = merged[["FWRKLWCT", "FSALCT", "FSEINCCT", "FMEDBNOP", "COVCONF", "FWKLIMCT", "ENGLANG", "EDUC1"]]
y = merged["FDMEDYN"]
X
# Out:
#        FWRKLWCT  FSALCT  FSEINCCT  FMEDBNOP  COVCONF  FWKLIMCT  ENGLANG  EDUC1
# 0           NaN       0         0       NaN      NaN         0      1.0      9
# 1           0.0       1         0       1.0      4.0         0      1.0     14
# 2           0.0       1         0       1.0      4.0         0      1.0     15
# 3           0.0       1         0       1.0      4.0         0      1.0     10
# 4           2.0       2         0       NaN      1.0         0      1.0     21
# ...         ...     ...       ...       ...      ...       ...      ...    ...
# 73728       0.0       1         0       NaN      1.0         0      1.0     17
# 73729       1.0       1         0       2.0      4.0         1      1.0     18
# 73730       2.0       2         0       NaN      2.0         0      1.0     18
# 73731       2.0       2         0       NaN      2.0         0      1.0     18
# 73732       NaN       0         0       NaN      NaN         0      1.0     14
#
# [73706 rows x 8 columns]

# %%
# change 2 to 0 so that yes is 1 and no is 0 for FMEDBNOP
X['FMEDBNOP'] = X['FMEDBNOP'].replace(2,0)
X
# Out:
# <ipython-input-35-6899a4fdb0fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['FMEDBNOP'] = X['FMEDBNOP'].replace(2,0)
#        FWRKLWCT  FSALCT  FSEINCCT  FMEDBNOP  COVCONF  FWKLIMCT  ENGLANG  EDUC1
# 0           NaN       0         0       NaN      NaN         0      1.0      9
# 1           0.0       1         0       1.0      4.0         0      1.0     14
# 2           0.0       1         0       1.0      4.0         0      1.0     15
# 3           0.0       1         0       1.0      4.0         0      1.0     10
# 4           2.0       2         0       NaN      1.0         0      1.0     21
# ...         ...     ...       ...       ...      ...       ...      ...    ...
# 73728       0.0       1         0       NaN      1.0         0      1.0     17
# 73729       1.0       1         0       0.0      4.0         1      1.0     18
# 73730       2.0       2         0       NaN      2.0         0      1.0     18
# 73731       2.0       2         0       NaN      2.0         0      1.0     18
# 73732       NaN       0         0       NaN      NaN         0      1.0     14
#
# [73706 rows x 8 columns]

# %% [markdown]
# Check for and fill null values

# %%
X.isnull().any()
# Out:
# FWRKLWCT    False
# FSALCT      False
# FSEINCCT    False
# FMEDBNOP    False
# COVCONF     False
# FWKLIMCT    False
# ENGLANG     False
# EDUC1       False
# dtype: bool

# %%
X['FWRKLWCT'] = X['FWRKLWCT'].fillna(26)
# Out:
# <ipython-input-43-4ee438341f6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['FWRKLWCT'] = X['FWRKLWCT'].fillna(26)

# %%
X['FMEDBNOP'] = X['FMEDBNOP'].fillna(3)
# Out:
# <ipython-input-44-cd35bcddf090>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['FMEDBNOP'] = X['FMEDBNOP'].fillna(3)

# %%
X['COVCONF'] = X['COVCONF'].fillna(10)
# Out:
# <ipython-input-45-3b0c488dbf5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['COVCONF'] = X['COVCONF'].fillna(10)

# %%
X['ENGLANG'] = X['ENGLANG'].fillna(10)
# Out:
# <ipython-input-46-a742306bdae8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['ENGLANG'] = X['ENGLANG'].fillna(10)

# %%
X
# Out:
#        FWRKLWCT  FSALCT  FSEINCCT  FMEDBNOP  COVCONF  FWKLIMCT  ENGLANG  EDUC1
# 0          26.0       0         0       3.0     10.0         0      1.0      9
# 1           0.0       1         0       1.0      4.0         0      1.0     14
# 2           0.0       1         0       1.0      4.0         0      1.0     15
# 3           0.0       1         0       1.0      4.0         0      1.0     10
# 4           2.0       2         0       3.0      1.0         0      1.0     21
# ...         ...     ...       ...       ...      ...       ...      ...    ...
# 73728       0.0       1         0       3.0      1.0         0      1.0     17
# 73729       1.0       1         0       0.0      4.0         1      1.0     18
# 73730       2.0       2         0       3.0      2.0         0      1.0     18
# 73731       2.0       2         0       3.0      2.0         0      1.0     18
# 73732      26.0       0         0       3.0     10.0         0      1.0     14
#
# [73706 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler as ss
sc = ss()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()

rf_model.fit(X_train, y_train)

y_pred_class = rf_model.predict(X_train)
training_accuracy = metrics.accuracy_score(y_train, y_pred_class)
training_error = 1 - training_accuracy

y_pred_class = rf_model.predict(X_test)
testing_accuracy = metrics.accuracy_score(y_test, y_pred_class)
testing_error = 1 - testing_accuracy
print("Test accuracy: {0}, Test error: {1}".format(testing_accuracy, testing_error))
# Out:
# Test accuracy: 0.8723375390042056, Test error: 0.12766246099579437

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.31      0.40      2041
#            2       0.90      0.96      0.93     12701
#
#     accuracy                           0.87     14742
#    macro avg       0.73      0.64      0.66     14742
# weighted avg       0.85      0.87      0.86     14742

# %%
# sort by highest feature importance
sorted_idx = rf_model.feature_importances_.argsort()
sorted_idx
X.columns[sorted_idx]
# Out:
# Index(['FSEINCCT', 'ENGLANG', 'FWKLIMCT', 'FWRKLWCT', 'COVCONF', 'FSALCT',
#        'EDUC1', 'FMEDBNOP'],
#       dtype='object')

# %%
# sort by highest feature importance
sorted_idx = rf_model.feature_importances_.argsort()
#plt.barh(X.columns[sorted_idx], rf_model.feature_importances_[sorted_idx], color='black')
plt.barh(X.columns[sorted_idx], rf_model.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
rf_model.feature_importances_[sorted_idx]
# Out:
# array([0.03949142, 0.05007172, 0.06564755, 0.07823248, 0.09338115,
#        0.10094791, 0.26351131, 0.30871647])

# %%
self_employed = merged[merged['PSEINC'] == 1]
self_employed
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 41       1      NaN         1    1    2.0      NaN     NaN     NaN      NaN
# 49       1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 90       1      NaN         1    1    2.0      NaN     NaN     NaN      NaN
# 99       1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 100      2      NaN         1    1    NaN      1.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73645    2      NaN         4    1    2.0      1.0     NaN     NaN      NaN
# 73647    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73653    1      NaN         4    2    NaN      2.0     NaN     NaN      NaN
# 73660    2      NaN         4    1    2.0      1.0     NaN     NaN      NaN
# 73717    2      NaN         4    2    NaN      1.0     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 41          1.0  ...      NaN        1         2         2       NaN     2
# 49          2.0  ...      3.0        1         2         1       NaN     2
# 90          1.0  ...      2.0        2         2         2       NaN     2
# 99          2.0  ...      3.0        2         2         2       NaN     2
# 100         1.0  ...      3.0        2         2         2       NaN     2
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73645       2.0  ...      NaN        4         2         2       NaN     2
# 73647       2.0  ...      4.0        2         2         2       NaN     2
# 73653       2.0  ...      NaN        3         2         2       NaN     2
# 73660       2.0  ...      NaN        1         2         2       NaN     2
# 73717       2.0  ...      2.0        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 41            1         1      2.0       0.0
# 49            2         1      2.0       2.0
# 90            1         1      2.0       1.0
# 99            2         1      2.0       1.0
# 100           2         1      2.0       1.0
# ...         ...       ...      ...       ...
# 73645         0         2      NaN       NaN
# 73647         3         1      2.0       1.0
# 73653         2         1      NaN       NaN
# 73660         3         1      NaN       NaN
# 73717         2         1      2.0       2.0
#
# [5414 rows x 730 columns]

# %%
y = self_employed['FDMEDYN']
y.value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
y.value_counts().sort_index()
# Out:
# 1     910
# 2    4504
# Name: FDMEDYN, dtype: int64

# %%
self_employed
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 41       1      NaN         1    1    2.0      NaN     NaN     NaN      NaN
# 49       1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 90       1      NaN         1    1    2.0      NaN     NaN     NaN      NaN
# 99       1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 100      2      NaN         1    1    NaN      1.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73645    2      NaN         4    1    2.0      1.0     NaN     NaN      NaN
# 73647    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73653    1      NaN         4    2    NaN      2.0     NaN     NaN      NaN
# 73660    2      NaN         4    1    2.0      1.0     NaN     NaN      NaN
# 73717    2      NaN         4    2    NaN      1.0     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 41          1.0  ...      NaN        1         2         2       NaN     2
# 49          2.0  ...      3.0        1         2         1       NaN     2
# 90          1.0  ...      2.0        2         2         2       NaN     2
# 99          2.0  ...      3.0        2         2         2       NaN     2
# 100         1.0  ...      3.0        2         2         2       NaN     2
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73645       2.0  ...      NaN        4         2         2       NaN     2
# 73647       2.0  ...      4.0        2         2         2       NaN     2
# 73653       2.0  ...      NaN        3         2         2       NaN     2
# 73660       2.0  ...      NaN        1         2         2       NaN     2
# 73717       2.0  ...      2.0        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 41            1         1      2.0       0.0
# 49            2         1      2.0       2.0
# 90            1         1      2.0       1.0
# 99            2         1      2.0       1.0
# 100           2         1      2.0       1.0
# ...         ...       ...      ...       ...
# 73645         0         2      NaN       NaN
# 73647         3         1      2.0       1.0
# 73653         2         1      NaN       NaN
# 73660         3         1      NaN       NaN
# 73717         2         1      2.0       2.0
#
# [5414 rows x 730 columns]

# %%
n_delay["FHICOVYN"].describe()
# Out:
# count    63401.000000
# mean         1.049447
# std          0.406725
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          9.000000
# Name: FHICOVYN, dtype: float64

# %%
y_delay["FHICOVYN"].describe()
# Out:
# count    10305.000000
# mean         1.105774
# std          0.387938
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          9.000000
# Name: FHICOVYN, dtype: float64

# %%
mean_height = 1.1058
stdev_height = 0.3879

# %%
mean_height + np.random.normal()*stdev_height
# Out:
# 0.7111591071543779

# %%
height_surveys = np.zeros((10000,10))
for i in range(height_surveys.shape[0]):
    for j in range(height_surveys.shape[1]):
        height_surveys[i,j] = mean_height +\
                              np.random.normal()*stdev_height
print('Mean Height:', round(np.mean(height_surveys)/12,1), 'feet')
print('Standard Deviation of Height:', 
      round(np.var(height_surveys)**0.5/12,1), 'foot')
# Out:
# Mean Height: 0.1 feet
# Standard Deviation of Height: 0.0 foot

# %%
# Histogram that shows the distribution for the mean of all surveys
# https://towardsdatascience.com/understanding-the-normal-distribution-with-python-e70bb855b027
fig, ax = plt.subplots(figsize=(12,8))
sns.distplot(np.mean(height_surveys,axis=1), 
             kde=False, label='Height')
ax.set_xlabel("Height in Inches",fontsize=16)
ax.set_ylabel("Frequency",fontsize=16)
plt.legend()
plt.tight_layout()

# %%
# Out:
# '2.5.0'
