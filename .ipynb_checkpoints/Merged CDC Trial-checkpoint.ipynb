# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %% [markdown]
# ### Load in data

# %%
family = pd.read_csv('familyxx.csv')
family.head()
# Out:
#    FINT_Y_P  FINT_M_P  FMX  RECTYPE  SRVY_YR  HHX  FM_SIZE  FM_STRCP  FM_TYPE  \
# 0      2018         1    1       60     2018    1        1        11        1
# 1      2018         1    1       60     2018    4        3        41        4
# 2      2018         2    1       60     2018    6        4        41        4
# 3      2018         3    1       60     2018    8        3        41        4
# 4      2018         2    1       60     2018    9        1        11        1
#
#    FM_STRP  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0       11  ...      NaN        1         2         2       NaN     2
# 1       41  ...      4.0        2         1         1       1.0     2
# 2       41  ...      1.0        2         2         2       NaN     1
# 3       41  ...      3.0        3         2         1       NaN     2
# 4       11  ...      NaN        2         1         1       1.0     2
#
#    FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0         1         1      NaN       NaN
# 1         3         1      2.0       3.0
# 2         4         1      2.0       4.0
# 3         3         1      2.0       3.0
# 4         1         1      2.0       0.0
#
# [5 rows x 127 columns]

# %%
person = pd.read_csv('personsx.csv')
person.head()
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  EDUC1  ERNYR_P  ARMFTM7P  ARMFTM1P  ARMFTM2P  ARMFTM3P  \
# 0       1.0  ...      9      NaN       NaN       NaN       NaN       NaN
# 1       2.0  ...     14      NaN       NaN       NaN       NaN       NaN
# 2       0.0  ...     15      7.0       NaN       NaN       NaN       NaN
# 3       NaN  ...     10      NaN       NaN       NaN       NaN       NaN
# 4       1.0  ...     21     11.0       NaN       NaN       NaN       NaN
#
#    ARMFTM4P  ARMFTM5P  ARMFTM6P  ENGLANG
# 0       NaN       NaN       NaN      1.0
# 1       NaN       NaN       NaN      1.0
# 2       NaN       NaN       NaN      1.0
# 3       NaN       NaN       NaN      1.0
# 4       NaN       NaN       NaN      1.0
#
# [5 rows x 602 columns]

# %%
household = pd.read_csv('househld.csv')
# household.head()

# %%
adult = pd.read_csv('samadult.csv')
# adult.head()

# %%
child = pd.read_csv('samchild.csv')
# child.head()

# %% [markdown]
# Having issues with merging --> possibly a file size issue, only working with smaller portions of each dataset

# %%
# merge family and person
# merged = pd.merge(person,family,on='FMX',how='outer')
merged = person.merge(family, on = 'FMX', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7ac998f4117> in <module>
#       1 # merge family and person
#       2 # merged = pd.merge(person,family,on='FMX',how='outer')
# ----> 3 merged_inner = person.merge(family, on = 'FMX', how='inner')
#
# NameError: name 'person' is not defined

# %%
merged.describe()
# Out:
#        FINT_Y_P     FINT_M_P          FMX  RECTYPE_x  SRVY_YR_x        HHX_x  \
# count    9802.0  9802.000000  9802.000000     9802.0     9802.0  9802.000000
# mean     2018.0     2.071312     1.000204       60.0     2018.0    83.174658
# std         0.0     0.811304     0.014284        0.0        0.0    48.868725
# min      2018.0     1.000000     1.000000       60.0     2018.0     1.000000
# 25%      2018.0     1.000000     1.000000       60.0     2018.0    40.000000
# 50%      2018.0     2.000000     1.000000       60.0     2018.0    82.000000
# 75%      2018.0     3.000000     1.000000       60.0     2018.0   124.000000
# max      2018.0     3.000000     2.000000       60.0     2018.0   177.000000
#
#            FM_SIZE     FM_STRCP      FM_TYPE      FM_STRP  ...        EDUC1  \
# count  9802.000000  9802.000000  9802.000000  9802.000000  ...  9800.000000
# mean      2.571108    25.915527     2.428280    25.905325  ...    18.140000
# std       1.407087    12.097291     1.169454    12.082447  ...    20.286508
# min       1.000000    11.000000     1.000000    11.000000  ...     0.000000
# 25%       2.000000    21.000000     2.000000    21.000000  ...    10.750000
# 50%       2.000000    21.000000     2.000000    21.000000  ...    15.000000
# 75%       3.000000    41.000000     4.000000    41.000000  ...    18.000000
# max       7.000000    45.000000     4.000000    45.000000  ...    96.000000
#
#            ERNYR_P   ARMFTM7P    ARMFTM1P    ARMFTM2P    ARMFTM3P    ARMFTM4P  \
# count  4704.000000  196.00000  294.000000  490.000000  392.000000  392.000000
# mean     34.312500    1.50000    3.666667    3.000000    1.500000    1.500000
# std      40.749043    0.50128    2.361041    2.002044    0.500639    0.500639
# min       1.000000    1.00000    2.000000    2.000000    1.000000    1.000000
# 25%       8.000000    1.00000    2.000000    2.000000    1.000000    1.000000
# 50%      10.000000    1.50000    2.000000    2.000000    1.500000    1.500000
# 75%      97.000000    2.00000    7.000000    2.000000    2.000000    2.000000
# max      99.000000    2.00000    7.000000    7.000000    2.000000    2.000000
#
#        ARMFTM5P   ARMFTM6P      ENGLANG
# count     196.0  196.00000  9212.000000
# mean        2.0    1.50000     1.340426
# std         0.0    0.50128     1.418446
# min         2.0    1.00000     1.000000
# 25%         2.0    1.00000     1.000000
# 50%         2.0    1.50000     1.000000
# 75%         2.0    2.00000     1.000000
# max         2.0    2.00000     8.000000
#
# [8 rows x 725 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9802 entries, 0 to 9801
# Columns: 728 entries, FINT_Y_P to ENGLANG
# dtypes: float64(622), int64(103), object(3)
# memory usage: 54.5+ MB

# %% [markdown]
# ### Income related factors

# %%
income = merged[['WRKHRS2', 'WRKFTALL', 'WRKLYR1', 'WRKMYR', 'ERNYR_P', 'HIEMPOF', 'PSAL', 'PSEINC', 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W']]
# healthcare visit related --> 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W'
# income realted --> 'WRKHRS2', 'WRKFTALL', 'WRKLYR1', 'WRKMYR', 'ERNYR_P', 'HIEMPOF', 'PSAL', 'PSEINC'

income
# Out:
#       WRKHRS2  WRKFTALL  WRKLYR1  WRKMYR  ERNYR_P  HIEMPOF  PSAL  PSEINC  \
# 0         NaN       NaN      2.0     NaN      NaN      NaN   2.0     2.0
# 1         NaN       NaN      2.0     NaN      NaN      NaN   2.0     2.0
# 2        32.0       1.0      1.0    12.0      7.0      1.0   1.0     2.0
# 3         NaN       NaN      NaN     NaN      NaN      NaN   NaN     NaN
# 4        40.0       NaN      1.0    12.0     11.0      1.0   1.0     2.0
# ...       ...       ...      ...     ...      ...      ...   ...     ...
# 9797      NaN       NaN      2.0     NaN      NaN      NaN   2.0     2.0
# 9798      NaN       NaN      2.0     NaN      NaN      NaN   2.0     2.0
# 9799     20.0       2.0      1.0    12.0      8.0      2.0   2.0     1.0
# 9800      NaN       NaN      NaN     NaN      NaN      NaN   NaN     NaN
# 9801      NaN       NaN      NaN     NaN      NaN      NaN   NaN     NaN
#
#       PHCDN2WP  P10DVYR  PHCPN2WP  PHCDV2W  PHCHM2W
# 0          1.0      2.0       1.0      1.0      2.0
# 1          NaN      9.0       NaN      2.0      2.0
# 2          NaN      9.0       NaN      2.0      2.0
# 3          NaN      9.0       NaN      2.0      2.0
# 4          NaN      2.0       NaN      2.0      2.0
# ...        ...      ...       ...      ...      ...
# 9797       1.0      2.0       NaN      1.0      2.0
# 9798       1.0      2.0       NaN      1.0      2.0
# 9799       NaN      1.0       NaN      2.0      2.0
# 9800       NaN      NaN       NaN      NaN      NaN
# 9801       NaN      NaN       NaN      NaN      NaN
#
# [9802 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(income.corr());

# %%
income.isnull().values.any()
# Out:
# True

# %%
# all columns have null values --> how should i deal with null values?
for i in income.columns:
    if(income[i].isnull().values.any()):
        print(i + '  True  ' + str(income[i].isnull().sum()))
    else:
        print(i + '  False')
# Out:
# WRKHRS2  True  5294
# WRKFTALL  True  9018
# WRKLYR1  True  2354
# WRKMYR  True  5098
# ERNYR_P  True  5098
# HIEMPOF  True  5098
# PSAL  True  2354
# PSEINC  True  2354
# PHCDN2WP  True  7352
# P10DVYR  True  2
# PHCPN2WP  True  9312
# PHCDV2W  True  2
# PHCHM2W  True  2

# %%
# fill null values with mean --> is this a good approach or should I take a different one?

pd.set_option('mode.chained_assignment', None)
for i in income.columns:
    income[i] = income[i].fillna(round(income[i].mean()))
# Out:
# array([2., 1.])

# %%
# remove values 7, 8, 9 (refused, not ascertained, don't know)
income = income[income['PHCHM2W'] < 7]
income.PHCHM2W.unique()
# Out:
# array([2., 1.])

# %%
income
# Out:
#       WRKHRS2  WRKFTALL  WRKLYR1  WRKMYR  ERNYR_P  HIEMPOF  PSAL  PSEINC  \
# 0        41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 1        41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 2        32.0       1.0      1.0    12.0      7.0      1.0   1.0     2.0
# 3        41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 4        40.0       2.0      1.0    12.0     11.0      1.0   1.0     2.0
# ...       ...       ...      ...     ...      ...      ...   ...     ...
# 9797     41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 9798     41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 9799     20.0       2.0      1.0    12.0      8.0      2.0   2.0     1.0
# 9800     41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
# 9801     41.0       2.0      2.0    11.0     34.0      2.0   2.0     2.0
#
#       PHCDN2WP  P10DVYR  PHCPN2WP  PHCDV2W  PHCHM2W
# 0          1.0      2.0       1.0      1.0      2.0
# 1          2.0      9.0       3.0      2.0      2.0
# 2          2.0      9.0       3.0      2.0      2.0
# 3          2.0      9.0       3.0      2.0      2.0
# 4          2.0      2.0       3.0      2.0      2.0
# ...        ...      ...       ...      ...      ...
# 9797       1.0      2.0       3.0      1.0      2.0
# 9798       1.0      2.0       3.0      1.0      2.0
# 9799       2.0      1.0       3.0      2.0      2.0
# 9800       2.0      2.0       3.0      2.0      2.0
# 9801       2.0      2.0       3.0      2.0      2.0
#
# [9802 rows x 13 columns]

# %%
X = income[['WRKHRS2', 'WRKFTALL', 'WRKLYR1', 'WRKMYR', 'ERNYR_P', 'HIEMPOF', 'PSAL', 'PSEINC']]
y = income['PHCHM2W']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler as ss
sc = ss()

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix
cm_test = confusion_matrix(y_pred, y_test)

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)

print()
print('Accuracy for training set for Random Forest = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for Random Forest = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))
# Out:
# Accuracy for training set for Random Forest = 0.9899234693877551
# Accuracy for test set for Random Forest = 0.9903061224489796

# %%
# sort by highest feature importance
sorted_idx = classifier.feature_importances_.argsort()
plt.barh(X.columns[sorted_idx], classifier.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
classifier.feature_importances_[sorted_idx]
# Out:
# array([0.00368149, 0.02712434, 0.08045441, 0.09075787, 0.12948271,
#        0.17223764, 0.2464533 , 0.24980823])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        19
#          2.0       0.99      1.00      1.00      1941
#
#     accuracy                           0.99      1960
#    macro avg       0.50      0.50      0.50      1960
# weighted avg       0.98      0.99      0.99      1960

# %%
factors = merged[['PLIMANY', 'LAHCC6', 'LAHCC7A', 'LAHCC8', 'LAHCC10', 'LAHCC11', 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W']]
# factors --> 'PLIMANY', 'LAHCC6', 'LAHCC7A', 'LAHCC8', 'LAHCC10', 'LAHCC11'
# healthcare visit --> 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W'

# %%
status_vars = merged[['LCCHRC1', 'LCCHRC2', 'LCCHRC3', 'LCCHRC4', 'LCCHRC5', 'LCCHRC6', 'LCCHRC8', 'LCCHRC9', 'LCCHRC10', 'LCCHRC11', 'LCCHRC12', 'LCCHRC13', 'LCCHRC90', 'LCCHRC91', 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W']]
# healthcare visit --> 'PHCDN2WP', 'P10DVYR', 'PHCPN2WP', 'PHCDV2W', 'PHCHM2W'
# status variables --> 'LCCHRC1', 'LCCHRC2', 'LCCHRC3', 'LCCHRC4', 'LCCHRC5', 'LCCHRC6', 'LCCHRC8', 'LCCHRC9', 'LCCHRC10', 'LCCHRC11', 'LCCHRC12', 'LCCHRC13', 'LCCHRC90', 'LCCHRC91'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(factors.corr());

# %%
sns.heatmap(status_vars.corr());

# %%
status_vars
# Out:
#       LCCHRC1  LCCHRC2  LCCHRC3  LCCHRC4  LCCHRC5  LCCHRC6  LCCHRC8  LCCHRC9  \
# 0         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 9797      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9798      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9799      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9800      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9801      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       LCCHRC10  LCCHRC11  LCCHRC12  LCCHRC13  LCCHRC90  LCCHRC91  PHCDN2WP  \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       1.0
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 9797       NaN       NaN       NaN       NaN       NaN       NaN       1.0
# 9798       NaN       NaN       NaN       NaN       NaN       NaN       1.0
# 9799       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9800       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9801       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#       P10DVYR  PHCPN2WP  PHCDV2W  PHCHM2W
# 0         2.0       1.0      1.0      2.0
# 1         9.0       NaN      2.0      2.0
# 2         9.0       NaN      2.0      2.0
# 3         9.0       NaN      2.0      2.0
# 4         2.0       NaN      2.0      2.0
# ...       ...       ...      ...      ...
# 9797      2.0       NaN      1.0      2.0
# 9798      2.0       NaN      1.0      2.0
# 9799      1.0       NaN      2.0      2.0
# 9800      NaN       NaN      NaN      NaN
# 9801      NaN       NaN      NaN      NaN
#
# [9802 rows x 19 columns]

# %%
merged['LCCHRC1']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9797   NaN
# 9798   NaN
# 9799   NaN
# 9800   NaN
# 9801   NaN
# Name: LCCHRC1, Length: 9802, dtype: float64

# %%
for i in ['LCCHRC1']:
    if(merged[i].isnull().values.any()):
        print(i + '  True  ' + str(merged[i].isnull().sum()))
    else:
        print(i + '  False')
# Out:
# LCCHRC1  True  9802

# %%
for i in ['LCCHRC1']:
    if(person[i].isnull().values.any()):
        print(i + '  True  ' + str(person[i].isnull().sum()))
    else:
        print(i + '  False')
# Out:
# LCCHRC1  True  72777

# %%
person
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 72826    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 72827    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 72828    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 72829    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 72830    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  EDUC1  ERNYR_P  ARMFTM7P  ARMFTM1P  ARMFTM2P  ARMFTM3P  \
# 0           1.0  ...      9      NaN       NaN       NaN       NaN       NaN
# 1           2.0  ...     14      NaN       NaN       NaN       NaN       NaN
# 2           0.0  ...     15      7.0       NaN       NaN       NaN       NaN
# 3           NaN  ...     10      NaN       NaN       NaN       NaN       NaN
# 4           1.0  ...     21     11.0       NaN       NaN       NaN       NaN
# ...         ...  ...    ...      ...       ...       ...       ...       ...
# 72826       1.0  ...      5      NaN       NaN       NaN       NaN       NaN
# 72827       1.0  ...     18      1.0       NaN       NaN       NaN       NaN
# 72828       1.0  ...     18     10.0       NaN       NaN       NaN       NaN
# 72829       2.0  ...     18     11.0       NaN       NaN       NaN       NaN
# 72830       1.0  ...     14      NaN       NaN       NaN       NaN       NaN
#
#        ARMFTM4P  ARMFTM5P  ARMFTM6P  ENGLANG
# 0           NaN       NaN       NaN      1.0
# 1           NaN       NaN       NaN      1.0
# 2           NaN       NaN       NaN      1.0
# 3           NaN       NaN       NaN      1.0
# 4           NaN       NaN       NaN      1.0
# ...         ...       ...       ...      ...
# 72826       NaN       NaN       NaN      3.0
# 72827       NaN       NaN       NaN      1.0
# 72828       NaN       NaN       NaN      1.0
# 72829       NaN       NaN       NaN      1.0
# 72830       NaN       NaN       NaN      1.0
#
# [72831 rows x 602 columns]
