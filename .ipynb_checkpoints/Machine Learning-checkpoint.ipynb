# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
family = pd.read_csv('familyxx.csv')
family["family_id"] = family["HHX"] + family["SRVY_YR"] + family["FMX"]
family.head()
# Out:
#    FINT_Y_P  FINT_M_P  FMX  RECTYPE  SRVY_YR  HHX  FM_SIZE  FM_STRCP  FM_TYPE  \
# 0      2018         1    1       60     2018    1        1        11        1
# 1      2018         1    1       60     2018    4        3        41        4
# 2      2018         2    1       60     2018    6        4        41        4
# 3      2018         3    1       60     2018    8        3        41        4
# 4      2018         2    1       60     2018    9        1        11        1
#
#    FM_STRP  ...  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  FHICOVCT  \
# 0       11  ...        1         2         2       NaN     2         1
# 1       41  ...        2         1         1       1.0     2         3
# 2       41  ...        2         2         2       NaN     1         4
# 3       41  ...        3         2         1       NaN     2         3
# 4       11  ...        2         1         1       1.0     2         1
#
#    FHICOVYN  FPRCOOH  FHIEBCCT  family_id
# 0         1      NaN       NaN       2020
# 1         1      2.0       3.0       2023
# 2         1      2.0       4.0       2025
# 3         1      2.0       3.0       2027
# 4         1      2.0       0.0       2028
#
# [5 rows x 128 columns]

# %%
person = pd.read_csv('personsx.csv')
person["family_id"] = person["HHX"] + person["SRVY_YR"] + person["FMX"]
person.head()
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  ERNYR_P  ARMFTM7P  ARMFTM1P  ARMFTM2P  ARMFTM3P  ARMFTM4P  \
# 0       1.0  ...      NaN       NaN       NaN       NaN       NaN       NaN
# 1       2.0  ...      NaN       NaN       NaN       NaN       NaN       NaN
# 2       0.0  ...      7.0       NaN       NaN       NaN       NaN       NaN
# 3       NaN  ...      NaN       NaN       NaN       NaN       NaN       NaN
# 4       1.0  ...     11.0       NaN       NaN       NaN       NaN       NaN
#
#    ARMFTM5P  ARMFTM6P  ENGLANG  family_id
# 0       NaN       NaN      1.0       2020
# 1       NaN       NaN      1.0       2023
# 2       NaN       NaN      1.0       2023
# 3       NaN       NaN      1.0       2023
# 4       NaN       NaN      1.0       2025
#
# [5 rows x 603 columns]

# %%
merged_inner = person.merge(family, on = 'family_id', how='inner')
merged_inner
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1        1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2        2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3        3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 73728    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73729    1      NaN         4    2    2.0      NaN     NaN     NaN      NaN
# 73730    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 73731    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 73732    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0           1.0  ...      NaN        1         2         2       NaN     2
# 1           2.0  ...      4.0        2         1         1       1.0     2
# 2           0.0  ...      4.0        2         1         1       1.0     2
# 3           NaN  ...      4.0        2         1         1       1.0     2
# 4           1.0  ...      1.0        2         2         2       NaN     1
# ...         ...  ...      ...      ...       ...       ...       ...   ...
# 73728       1.0  ...      1.0        1         2         2       NaN     2
# 73729       1.0  ...      4.0        5         1         1       2.0     2
# 73730       1.0  ...      2.0        2         2         2       NaN     2
# 73731       2.0  ...      2.0        2         2         2       NaN     2
# 73732       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0             1         1      NaN       NaN
# 1             3         1      2.0       3.0
# 2             3         1      2.0       3.0
# 3             3         1      2.0       3.0
# 4             4         1      2.0       4.0
# ...         ...       ...      ...       ...
# 73728         1         1      NaN       1.0
# 73729         1         1      2.0       1.0
# 73730         2         1      2.0       2.0
# 73731         2         1      2.0       2.0
# 73732         1         1      2.0       0.0
#
# [73733 rows x 730 columns]

# %% [markdown]
# Accessibility Factors
# HIEMPOF --> Health insurance offered at workplace
# ENGLANG --> How well English is spoken
# FMEDBILL --> Problems paying or unable to pay any medical bills
# FOWBENYN --> Any family member receive other kind of welfare assistance
# (in adult dataset) PDSICKA --> Paid sick leave at current or most recent job
# FDMEDYN --> Any family member delay* seeking medical care, 12m?
#
#
# Behavioral Factors
# PHCHN2WP --> Number of HOME visits by health professional, 2wk
# PHCPN2WP --> Number of PHONE calls to health professional, 2wk
# PHCDN2WP --> Number of times VISITED health professional, 2wk
# P10DVYR --> Did - - receive care 10+ times, 12m
#
# Predicting: FLAADLYN --> Any family member need help with an ADL?

# %%
model = merged_inner[["HIEMPOF", "ENGLANG", "FMEDBILL", "FOWBENYN", "FDMEDYN", "P10DVYR", "FLAADLYN"]]

# %%
model = model[model["FLAADLYN"] < 7]

# %%
# for checking number of null values
for i in ['FLAADLYN']:
    if(model[i].isnull().values.any()):
        print(i + '  True  ' + str(model[i].isnull().sum()))
    else:
        print(i + '  False')
# Out:
# FLAADLYN  False

# %%
model.loc[model["FLAADLYN"] == 1]
# Out:
#        HIEMPOF  ENGLANG  FMEDBILL  FOWBENYN  FDMEDYN  P10DVYR  FLAADLYN
# 11         NaN      1.0         1         2        1        1         1
# 63         NaN      1.0         2         1        2        1         1
# 64         NaN      1.0         2         1        2        1         1
# 65         NaN      1.0         2         1        2        2         1
# 109        NaN      1.0         2         2        2        1         1
# ...        ...      ...       ...       ...      ...      ...       ...
# 73589      NaN      1.0         2         2        2        1         1
# 73590      NaN      1.0         2         2        2        1         1
# 73662      NaN      1.0         2         2        2        2         1
# 73663      NaN      1.0         2         2        2        2         1
# 73706      NaN      1.0         1         2        2        2         1
#
# [3805 rows x 7 columns]

# %%
model.loc[model["FLAADLYN"] == 2]
# Out:
#        HIEMPOF  ENGLANG  FMEDBILL  FOWBENYN  FDMEDYN  P10DVYR  FLAADLYN
# 0          NaN      1.0         2         2        2        2         2
# 1          NaN      1.0         1         2        1        9         2
# 2          1.0      1.0         1         2        1        9         2
# 3          NaN      1.0         1         2        1        9         2
# 4          1.0      1.0         2         2        2        2         2
# ...        ...      ...       ...       ...      ...      ...       ...
# 73728      1.0      1.0         2         2        2        2         2
# 73729      1.0      1.0         1         2        1        1         2
# 73730      1.0      1.0         2         2        2        2         2
# 73731      1.0      1.0         2         2        2        2         2
# 73732      NaN      1.0         2         2        2        2         2
#
# [69911 rows x 7 columns]

# %%
model = model.drop(model.query('FLAADLYN == 2').sample(frac=.95).index)

# %%
for i in model.columns:
    model[i] = model[i].fillna(round(0))
model
# Out:
#        HIEMPOF  ENGLANG  FMEDBILL  FOWBENYN  FDMEDYN  P10DVYR  FLAADLYN
# 6          2.0      1.0         2         2        2        2         2
# 8          1.0      1.0         2         2        2        2         2
# 11         2.0      1.0         1         2        1        1         1
# 63         2.0      1.0         2         1        2        1         1
# 64         2.0      1.0         2         1        2        1         1
# ...        ...      ...       ...       ...      ...      ...       ...
# 73706      2.0      1.0         1         2        2        2         1
# 73710      1.0      1.0         2         2        2        2         2
# 73718      1.0      1.0         2         2        2        2         2
# 73723      2.0      1.0         2         2        2        2         2
# 73731      1.0      1.0         2         2        2        2         2
#
# [7301 rows x 7 columns]

# %%
X = model[["HIEMPOF", "ENGLANG", "FMEDBILL", "FOWBENYN", "FDMEDYN", "P10DVYR"]]
y = model["FLAADLYN"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler as ss
sc = ss()

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()

rf_model.fit(X_train, y_train)

y_pred_class = rf_model.predict(X_train)
training_accuracy = metrics.accuracy_score(y_train, y_pred_class)
training_error = 1 - training_accuracy

y_pred_class = rf_model.predict(X_test)
testing_accuracy = metrics.accuracy_score(y_test, y_pred_class)
testing_error = 1 - testing_accuracy
print("Test accuracy: {0}, Test error: {1}".format(testing_accuracy, testing_error))
# Out:
# Test accuracy: 0.6570841889117043, Test error: 0.3429158110882957

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.56      0.62       728
#            2       0.63      0.76      0.69       733
#
#     accuracy                           0.66      1461
#    macro avg       0.66      0.66      0.65      1461
# weighted avg       0.66      0.66      0.65      1461

# %%
# sort by highest feature importance
sorted_idx = rf_model.feature_importances_.argsort()
plt.barh(X.columns[sorted_idx], rf_model.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
rf_model.feature_importances_[sorted_idx]
# Out:
# array([0.05277895, 0.09000131, 0.09747447, 0.13934128, 0.29754308,
#        0.32286091])
